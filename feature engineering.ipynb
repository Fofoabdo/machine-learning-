# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv('Ecommerce Customers')
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df=data['Address']

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data1=data['Address']
df = pd.DataFrame(data1)

# define a lambda function to split the address string into street, city/state, and zip
split_address = lambda x: pd.Series([x[0].strip(), ' '.join(x[1:-1]).strip(), x[-1].strip()])

# apply the lambda function to the address column to create new columns for street, city/state, and zip
df[['street', 'city_state', 'zip']] = df['Address'].str.split().apply(split_address)

# split the city_state column into city and state
df[['city', 'state']] = df['city_state'].str.split(',', expand=True)

# drop the original address and city_state columns

df=pd.DataFrame(df)

df
# Out:
#                                                Address street  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605    835
# 1       4547 Archer Common\nDiazchester, CA 06566-8576   4547
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...  24645
# 3     1414 David Throughway\nPort Jason, OH 22070-1220   1414
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  14023
# ..                                                 ...    ...
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...   4483
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320    172
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...   0787
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...    680
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...  49791
#
#                                        city_state         zip  \
# 0                    Frank Tunnel Wrightmouth, MI  82180-9605
# 1                   Archer Common Diazchester, CA  06566-8576
# ...

# %%
data['street']=df['street']
data['city_state']=df['city_state']
data['zip']=df['zip']
data['city']=df['city']
data['state']=df['state']

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
# create a sample DataFrame with an email column
data2=data['Email']
df = pd.DataFrame(data2)

# use the str.split() method to split the email column into two parts: the name and the domain
df[['name', 'domain']] = df['Email'].str.split('@', expand=True)

# use string slicing to extract the part of the domain that represents the email type
df['type'] = df['domain'].str.split('.', expand=True)[0]

# drop the original email and domain columns
df = df.drop(['Email', 'domain'], axis=1)
# Out:
#               name             type
# 0      mstephenson        fernandez
# 1            hduke          hotmail
# 2           pallen            yahoo
# 3    riverarebecca            gmail
# 4        mstephens  davidson-herman
# ..             ...              ...
# 495   lewisjessica      craig-evans
# 496      katrina56            gmail
# 497         dale88          hotmail
# 498        cwilson          hotmail
# 499   hannahwilson         davidson
#
# [500 rows x 2 columns]

# %%
df2=pd.DataFrame(df)
df2
# Out:
#               name             type
# 0      mstephenson        fernandez
# 1            hduke          hotmail
# 2           pallen            yahoo
# 3    riverarebecca            gmail
# 4        mstephens  davidson-herman
# ..             ...              ...
# 495   lewisjessica      craig-evans
# 496      katrina56            gmail
# 497         dale88          hotmail
# 498        cwilson          hotmail
# 499   hannahwilson         davidson
#
# [500 rows x 2 columns]

# %%
data['name']=df2['name']
data['type']=df2['type']

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
customers=data.to_csv('customers')
